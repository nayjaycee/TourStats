# %%
from Scripts.weekly_view import build_weekly_view

weekly_raw = build_weekly_view(2024, 6)  # same event as your pick row
weekly_filtered, used_ids = apply_used_filter_to_weekly(weekly_raw.copy(), paths.picks_path)

print("used_ids:", used_ids)
print("used_ids contains 8825:", 8825 in set(map(int, used_ids)))

raw_ids = set(weekly_raw["summary"]["dg_id"].dropna().astype(int))
flt_ids = set(weekly_filtered["summary"]["dg_id"].dropna().astype(int))

print("raw has 8825:", 8825 in raw_ids)
print("filtered has 8825:", 8825 in flt_ids)
# Out:
# /Users/joshmacbook/python_projects/OAD/Scripts/features.py:101: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(_player_rolling_for_windows, windows=windows)
# /Users/joshmacbook/python_projects/OAD/Scripts/features.py:289: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(_agg_event)
# /Users/joshmacbook/python_projects/OAD/Scripts/features.py:351: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(_agg_player)
# /Users/joshmacbook/python_projects/OAD/Scripts/features.py:289: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(_agg_event)
# /Users/joshmacbook/python_projects/OAD/Scripts/features.py:351: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(_agg_player)
# /Users/joshmacbook/python_projects/OAD/Scripts/features.py:101: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(_player_rolling_for_windows, windows=windows)
# /Users/joshmacbook/python_projects/OAD/Scripts/patterns.py:123: RuntimeWarning: All-NaN slice encountered
#   out.min_ytd_starts = float(np.nanmedian(feat["ytd_starts"]))
# /Users/joshmacbook/python_projects/OAD/Scripts/patterns.py:126: RuntimeWarning: All-NaN slice encountered
#   val = np.nanmedian(feat["ytd_made_cut_pct"])
# /Users/joshmacbook/python_projects/OAD/Scripts/patterns.py:135: RuntimeWarning: All-NaN slice encountered
#   val = np.nanmedian(feat[col])
# /Users/joshmacbook/python_projects/OAD/Scripts/patterns.py:327: RuntimeWarning: All-NaN slice encountered
#   med_ytd_cut = np.nanmedian(winners_features["ytd_made_cut_pct"])
# /Users/joshmacbook/python_projects/OAD/Scripts/patterns.py:339: RuntimeWarning: All-NaN slice encountered
#   med_val = np.nanmedian(winners_features[col])
# /Users/joshmacbook/python_projects/OAD/Scripts/patterns.py:380: RuntimeWarning: All-NaN slice encountered
#   med_ytd_cut_t = np.nanmedian(top5_features["ytd_made_cut_pct"])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from Scripts.weekly_view import build_weekly_view
#       3 weekly_raw = build_weekly_view(2024, 6)  # same event as your pick row
# ----> 4 weekly_filtered, used_ids = apply_used_filter_to_weekly(weekly_raw.copy(), paths.picks_path)
#       6 print("used_ids:", used_ids)
#       7 print("used_ids contains 8825:", 8825 in set(map(int, used_ids)))
#
# NameError: name 'apply_used_filter_to_weekly' is not defined
